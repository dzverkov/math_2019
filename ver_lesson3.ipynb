# %%
import numpy as np
from math import factorial

# %%
def combinations(n, k):
    return int(factorial(n) / (factorial(k) * factorial(n - k)))

# %% [markdown]
# ### Задание 1

# %% [markdown]
# Даны значения зарплат из выборки выпускников: 100, 80, 75, 77, 89, 33, 45, 25, 65, 17, 30, 24, 57, 55, 70, 75, 65, 84, 90, 150. Посчитать (желательно без использования статистических методов наподобие std, var, mean) среднее арифметическое, среднее квадратичное отклонение, смещенную и несмещенную оценки дисперсий для данной выборки.

# %%
a = np.array([100, 80, 75, 77, 89, 33, 45, 25, 65, 17, 30, 24, 57, 55, 70, 75, 65, 84, 90, 150])
mean = a.sum()/len(a)
std = np.sqrt(np.array([(i-mean)**2 for i in a]).sum()/len(a))
hv = np.array([(i-mean)**2 for i in a]).sum()/len(a)
hv2 = np.array([(i-mean)**2 for i in a]).sum()/(len(a)-1)
print(f"Среднее арифметическое = {mean}")
print(f"Среднее квадратичное отклонение = {std}")
print(f"Смещенная оценка дисперсии = {hv}")
print(f"Несмещенная оценка дисперсии = {hv2}")
# Out:
# Среднее арифметическое = 65.3
# Среднее квадратичное отклонение = 30.823854398825596
# Смещенная оценка дисперсии = 950.11
# Несмещенная оценка дисперсии = 1000.1157894736842

# %% [markdown]
# ### Задание 2

# %% [markdown]
# В первом ящике находится 8 мячей, из которых 5 - белые. Во втором ящике - 12 мячей, из которых 5 белых. Из первого ящика вытаскивают случайным образом два мяча, из второго - 4. Какова вероятность того, что 3 мяча белые?

# %%
# Из первого ящика берём 2 белых, а из второго 1 белый
p1 = (combinations(5, 2)*combinations(3, 0)/combinations(8, 2))*(combinations(5, 1)*combinations(7, 3)/combinations(12, 4))
# Из первого ящика берём 1 белых, а из второго 2 белых
p2 = (combinations(5, 1)*combinations(3, 1)/combinations(8, 2))*(combinations(5, 2)*combinations(7, 2)/combinations(12, 4))
# Из первого ящика берём 0 белых, а из второго 3 белых
p3 = (combinations(5, 0)*combinations(3, 2)/combinations(8, 2))*(combinations(5,3)*combinations(7, 1)/combinations(12, 4))

p1+p2+p3
# Out:
# 0.3686868686868687

# %% [markdown]
# ### Задание 3

# %% [markdown]
# На соревновании по биатлону один из трех спортсменов стреляет и попадает в мишень. Вероятность попадания для первого спортсмена равна 0.9, для второго — 0.8, для третьего — 0.6. Найти вероятность того, что выстрел произведен: a). первым спортсменом б). вторым спортсменом в). третьим спортсменом.

# %%
# Вероятности попадания
p1 = 0.9
p2 = 0.8
p3 = 0.6
# Вероятность произвести выстрел у каждого стрелка равна 1/3, тогда вероятность попадания равна:
pA = 1/3*p1 + 1/3*p2 + 1/3*p3
P1 = 1/3*p1/pA
P2 = 1/3*p2/pA
P3 = 1/3*p3/pA

print(f"Вероятность, что выстрел произведён первым спортсменом: {P1}")
print(f"Вероятность, что выстрел произведён вторым спортсменом: {P2}")
print(f"Вероятность, что выстрел произведён третьим спортсменом: {P3}")
# Out:
# Вероятность, что выстрел произведён первым спортсменом: 0.391304347826087
# Вероятность, что выстрел произведён вторым спортсменом: 0.3478260869565218
# Вероятность, что выстрел произведён третьим спортсменом: 0.2608695652173913

# %% [markdown]
# ### Задание 4

# %% [markdown]
# В университет на факультеты A и B поступило равное количество студентов, а на факультет C студентов поступило столько же, сколько на A и B вместе. Вероятность того, что студент факультета A сдаст первую сессию, равна 0.8. Для студента факультета B эта вероятность равна 0.7, а для студента факультета C - 0.9. Студент сдал первую сессию. Какова вероятность, что он учится: a). на факультете A б). на факультете B в). на факультете C?

# %%
# Вероятности сдачи сессии
pa = 0.8
pb = 0.7
pc = 0.9
# Вероятность, что студент будет из факультета A или B равна 1/4, а из C - 1/2, т.к. там учится в 2 раза больше студентов
pA = 1/4*pa + 1/4*pb + 1/2*pc
P1 = 1/4*pa/pA
P2 = 1/4*pb/pA
P3 = 1/2*pc/pA

print(f"Вероятность, что студент из факультета A: {P1}")
print(f"Вероятность, что студент из факультета B: {P2}")
print(f"Вероятность, что студент из факультета C: {P3}")
# Out:
# Вероятность, что студент из факультета A: 0.24242424242424246
# Вероятность, что студент из факультета B: 0.21212121212121213
# Вероятность, что студент из факультета C: 0.5454545454545455

# %% [markdown]
# ### Задание 5

# %% [markdown]
# Устройство состоит из трех деталей. Для первой детали вероятность выйти из строя в первый месяц равна 0.1, для второй - 0.2, для третьей - 0.25. Какова вероятность того, что в первый месяц выйдут из строя: а). все детали б). только две детали в). хотя бы одна деталь г). от одной до двух деталей?

# %%
# все детали
p1 = 0.1
p2 = 0.2
p3 = 0.25
P1 = p1*p2*p3
print(f"Вероятность выхода всех деталей: {P1}")
# только две детали
P2 = p1*p2*(1-p3)+p1*(1-p2)*p3+(1-p1)*p2*p3
print(f"Вероятность выхода двух деталей: {P2}")
# хотя бы одна деталь
P3 = 1 - (1-p1)*(1-p2)*(1-p3)
print(f"Вероятность выхода хотя бы одной детали: {P3}")
# от одной до двух деталей
P4 = P2 + (p1*(1-p2)*(1-p3)+(1-p1)*(1-p2)*p3+(1-p1)*p2*(1-p3))
print(f"Вероятность выхода от одной до двух деталей: {P4}")
# Out:
# Вероятность выхода всех деталей: 0.005000000000000001
# Вероятность выхода двух деталей: 0.08000000000000002
# Вероятность выхода хотя бы одной детали: 0.45999999999999996
# Вероятность выхода от одной до двух деталей: 0.45500000000000007
