# %%
import numpy as np

# %%
def Mx(a,b):
    return (a + b)/2;

# %%
def Dx(a,b):
    return (b - a)**2/12

# %% [markdown]
# ### Задание 1

# %% [markdown]
# Случайная непрерывная величина A имеет равномерное распределение на промежутке (200, 800].
# Найдите ее среднее значение и дисперсию.

# %%
print(f"M(x)= {Mx(200,800)}")
print(f"D(x)= {Dx(200,800)}")
# Out:
# M(x)= 500.0
# D(x)= 30000.0

# %% [markdown]
# О случайной непрерывной равномерно распределенной величине B известно, что ее дисперсия равна 0.2.
# Можно ли найти правую границу величины B и ее среднее значение зная, что левая граница равна 0.5?
# Если да, найдите ее.

# %%
D = 0.2
a = 0.5
# Из формулы дисперсии для равномерно распределённый последовательности выводим правую границу
b = np.sqrt(D * 12) + a
print(f"b = {b}")
print(f"M(x)= {Mx(a,b)}")
# Out:
# b = 2.049193338482967
# M(x)= 1.2745966692414834

# %% [markdown]
# Непрерывная случайная величина X распределена нормально и задана плотностью распределения
#     f(x) = (1 / (4 * sqrt(2*pi))) * (exp(-(x+2)^2) / 32).
# Найдите:
# а). M(X)
# б). D(X)
# в). std(X) (среднее квадратичное отклонение)

# %%
# В формуле похоже опечатка, видимо должно быть так - f(x)=(1/(4*sqrt(2*pi)))*(exp(-(x+2)**2/32))
# Из формулы плотности вероятностей получаем, что 
sigma = 4
# можно проверить по правой части формулы: 2*sigma**2 = 2*4**2 = 32
a = -2

print(f"M(x)= {-2}")
print(f"D(x)= {sigma**2}")
print(f"std(x)= {sigma}")
# Out:
# M(x)= -2
# D(x)= 16
# std(x)= 4

# %% [markdown]
# Рост взрослого населения города X имеет нормальное распределение.
# Причем, средний рост равен 174 см, а среднее квадратичное отклонение равно 8 см.
# Какова вероятность того, что случайным образом выбранный взрослый человек имеет рост:
# а). больше 182 см
# б). больше 190 см
# в). от 166 см до 190 см
# г). от 166 см до 182 см
# д). от 158 см до 190 см
# е). не выше 150 см или не ниже 190 см
# ё). не выше 150 см или не ниже 198 см
# ж). ниже 166 см

# %%
Mx = 174
std_ = 8
# а). больше 182 см
Z = (182 - Mx)/std_
P = 1 - 0.8413
print(f"больше 182 см: P = {P}")
# б). больше 190 см
Z = (190 - Mx)/std_
P = 1 - 0.9772
print(f"больше 190 см: P = {P}")
# в). от 166 см до 190 см
Z1 = (190 - Mx)/std_
P1 = 0.9772
Z2 = (166 - Mx)/std_
P2 = 0.1587
P = P1 - P2
print(f"от 166 см до 190 см: P = {P}")
# г). от 166 см до 182 см
Z1 = (182 - Mx)/std_
P1 = 0.8413
Z2 = (166 - Mx)/std_
P2 = 0.1587
P = P1 - P2
print(f"от 166 см до 182 см: P = {P}")
# д). от 158 см до 190 см
Z1 = (190 - Mx)/std_
P1 = 0.9772
Z2 = (158 - Mx)/std_
P2 = 0.0228
P = P1 - P2
print(f"от 158 см до 190 см: P = {P}")
# е). не выше 150 см или не ниже 190 см
Z1 = (190 - Mx)/std_
P1 = 1 - 0.9772
Z2 = (150 - Mx)/std_
P2 = 0.0013
P = P1 + P2
print(f"не выше 150 см или не ниже 190 см: P = {P}")
# ё). не выше 150 см или не ниже 198 см
Z1 = (198 - Mx)/std_
P1 = 1 - 0.9987
Z2 = (150 - Mx)/std_
P2 = 0.0013
P = P1 + P2
print(f"не выше 150 см или не ниже 198 см: P = {P}")
#ж). ниже 166 см
Z = (166 - Mx)/std_
P = 0.1587
print(f"ниже 166 см: P = {P}")
# Out:
# больше 182 см: P = 0.15869999999999995
# больше 190 см: P = 0.022800000000000042
# от 166 см до 190 см: P = 0.8185
# от 166 см до 182 см: P = 0.6826000000000001
# от 158 см до 190 см: P = 0.9543999999999999
# не выше 150 см или не ниже 190 см: P = 0.02410000000000004
# не выше 150 см или не ниже 198 см: P = 0.002599999999999968
# ниже 166 см: P = 0.1587

# %% [markdown]
# На сколько сигм (средних квадратичных отклонений) отклоняется рост человека, равный 190 см, от
# математического ожидания роста в популяции, в которой M(X) = 178 см и D(X) = 25 кв.см?

# %%
std_ = np.sqrt(25)
Z = (190 - 178)/std_
Z
# Out:
# 2.4
